# %% [markdown]
# # STOP HERE!  DEATH COUNT SPOILERS BELOW...

# %% [markdown]
# ---

# %% [markdown]
# # Recap - Things we already have:
# - Episode ratings from IMDb
# - Episode user-voter turnouts from IMDb
# - Dialogue; text data
#     - Dialogue length per episode
#     - Dialogue uniqueness per episode
#     - Dialogue sentiment per episode
# - Kill count per episode...

# %% [markdown]
# # Other things that would be nice to have:
# - dialogue data by character, by episode
# - screen time by character, by episode

# %% [markdown]
# # Next steps:
# - Use these variables in an OLS regression to see if there is a statistically significant association between a variable and an episode's epicness.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
tables:
    kill_count
    token_count
    token_sentiment

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('got.db')
c = conn.cursor()
c.execute('''SELECT * FROM kill_count''')
df = pd.DataFrame(c.fetchall())
df.columns = [i[0] for i in c.description]
df = df.drop('index',axis=1)
df
# Out:
#                              death season episode epID
# 0                     Waymar Royce      1       1  101
# 1                            Gared      1       1  101
# 2                             Will      1       1  101
# 3                        Jon Arryn      1       1  101
# 4                 Catspaw assassin      1       2  102
# 5                             Lady      1       2  102
# 6                            Mycah      1       2  102
# 7                         Ser Hugh      1       4  104
# 8                         Kurleket      1       5  105
# 9                      Willis Wode      1       5  105
# 10                     Jory Cassel      1       5  105
# 11                             Wyl      1       5  105
# 12                          Heward      1       5  105
# 13                          Wallen      1       6  106
# 14                            Stiv      1       6  106
# 15                     Vardis Egen      1       6  106
# ...
